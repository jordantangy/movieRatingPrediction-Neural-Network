# %% [markdown]
# <a href="https://colab.research.google.com/github/jordantangy/movieRatingPrediction-Neural-Network/blob/main/Movie%20Rating%20Prediction%20ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow.compat.v1 as tf
import math
import pandas as pd

# retrieve data for specific user(userId, movieId,rating) and separating training set and test set
tf.disable_v2_behavior()
df = pd.read_csv('/content/drive/MyDrive/ratings.csv', usecols=['userId', 'movieId', 'rating'], low_memory=False)
temp = df.to_numpy()
print(temp)
temp_mat = []
np.set_printoptions(suppress=True)
counter = 0
for row in temp:
    if (row[0] == 48):
        temp_mat.append(row)
user_mat = np.array(temp_mat)
user_mat_len = len(user_mat)
training_len = math.floor((user_mat_len * 80) / 100)
test_len = user_mat_len - training_len

temp_train = []
x = range(0, training_len)
for i in x:
    row = user_mat[i]
    temp_train.append(row)
training_data = np.array(temp_train)

temp_test = []
y = range(training_len, user_mat_len)
for i in y:
    row = user_mat[i]
    temp_test.append(row)
test_data = np.array(temp_test)

# creating neural network and training

print("started training...")
features = 1128
df = pd.read_csv('/content/drive/MyDrive/genome-scores.csv', usecols=['movieId', 'relevance'], low_memory=False)
relevance = df.to_numpy()
x = tf.placeholder(tf.float32, shape=[1, features])
y_ = tf.placeholder(tf.float32, [1])
W = tf.Variable(tf.zeros([features, 1]))
b = tf.Variable(tf.zeros([1]))
y = tf.matmul(x, W) + b
loss = tf.reduce_mean(tf.pow(y - y_, 2))
update = tf.train.GradientDescentOptimizer(0.001).minimize(loss)
sess = tf.Session()
sess.run(tf.global_variables_initializer())
# saver.save(sess, 'my-model', global_step=1000)
for i in range(len(training_data)):
    print("----------------------------------------------------------------------")
    print("Movie : ", i+1, "/", len(training_data))
    movieId = training_data[i][1]
    data_y = [training_data[i][2]]
    temp_mat = []
    np.set_printoptions(suppress=True)
    for j in range(len(relevance)):
        if (relevance[j][0] == movieId):
            temp_mat.append(relevance[j][1])
    data_x = [np.array(temp_mat)]
    for k in range(0, 20000):
        sess.run(update, feed_dict={x: data_x, y_: data_y})
        w_updated = W.eval(sess)
        b_updated = b.eval(sess)
        if k % 100000 == 0:
            print('Iteration:', k, ' W:', sess.run(W), ' b:', sess.run(b), ' loss:',
                  loss.eval(session=sess, feed_dict={x: data_x, y_: data_y}))

# testing the NN


print("starting testing...")

for i in range(len(test_data)):
    print("----------------------------------------------------------------------")
    print("Movie : ", i + 1, "/", len(test_data))
    movieId = test_data[i][1]
    actual = test_data[i][2]
    # data_y = [test_data[i][2]]
    temp_mat = []
    np.set_printoptions(suppress=True)
    for j in range(len(relevance)):
        if (relevance[j][0] == movieId):
            temp_mat.append(relevance[j][1])
    data_x = [np.array(temp_mat)]
    print(data_x)
    pred = np.matmul(data_x, w_updated) + b_updated
    print("For Movie : ", i + 1, "/", len(test_data), "the prediction is:", pred, "and the actual rating is", actual)
# Out:
# [[   1.   296.     5. ]
#  [   1.   306.     3.5]
#  [   1.   307.     5. ]
#  ...
#  [7045.  4857.     4. ]
#  [7045.  4886.     5. ]
#  [7045.  4896.     4. ]]
# started training...
# ----------------------------------------------------------------------
# Movie :  1 / 20
# Iteration: 0  W: [[0.0000935]
#  [0.000111 ]
#  [0.0000585]
#  ...
#  [0.000036 ]
#  [0.000182 ]
#  [0.0000355]]  b: [0.002]  loss: 0.90306735
# ----------------------------------------------------------------------
# Movie :  2 / 20
# Iteration: 0  W: [[0.002057  ]
#  [0.002451  ]
#  [0.00133236]
#  ...
#  [0.00077746]
#  [0.00401749]
#  [0.00077967]]  b: [0.04432789]  loss: 3.6775494
# ----------------------------------------------------------------------
# Movie :  3 / 20
# Iteration: 0  W: [[0.00485614]
#  [0.00587014]
#  [0.00379839]
#  ...
#  [0.00166314]
#  [0.00983127]
#  [0.00187096]]  b: [0.1107367]  loss: 3.2252598
# ----------------------------------------------------------------------
# Movie :  4 / 20
# Iteration: 0  W: [[0.00552661]
#  [0.00644908]
#  [0.00434071]
#  ...
#  [0.00206935]
#  [0.0119806 ]
#  [0.00238398]]  b: [0.13319807]  loss: 0.04217995
# ----------------------------------------------------------------------
# Movie :  5 / 20
# Iteration: 0  W: [[0.00545634]
#  [0.0063724 ]
#  [0.00417093]
#  ...
#  [0.00196457]
#  [0.01167725]
#  [0.00232264]]  b: [0.12973328]  loss: 0.28054652
# ----------------------------------------------------------------------
# Movie :  6 / 20
# Iteration: 0  W: [[0.00573032]
#  [0.00660306]
#  [0.00436478]
#  ...
#  [0.00208822]
#  [0.01232675]
#  [0.002476  ]]  b: [0.13763648]  loss: 0.34918302
# ----------------------------------------------------------------------
# Movie :  7 / 20
# Iteration: 0  W: [[0.00589889]
#  [0.00674501]
#  [0.00453705]
#  ...
#  [0.0021899 ]
#  [0.01296365]
#  [0.00261105]]  b: [0.14524461]  loss: 0.28676695
# ----------------------------------------------------------------------
# Movie :  8 / 20
# Iteration: 0  W: [[0.00539965]
#  [0.00625326]
#  [0.00361022]
#  ...
#  [0.00201836]
#  [0.01147541]
#  [0.00229003]]  b: [0.12852837]  loss: 2.2617111
# ----------------------------------------------------------------------
# Movie :  9 / 20
# Iteration: 0  W: [[0.0055337 ]
#  [0.00615547]
#  [0.00334485]
#  ...
#  [0.00184717]
#  [0.01050894]
#  [0.00202264]]  b: [0.11791418]  loss: 1.5388668
# ----------------------------------------------------------------------
# Movie :  10 / 20
# Iteration: 0  W: [[0.01143642]
#  [0.00840739]
#  [0.00428961]
#  ...
#  [0.00230234]
#  [0.01453713]
#  [0.00277599]]  b: [0.15659969]  loss: 1.3034605
# ----------------------------------------------------------------------
# Movie :  11 / 20
# Iteration: 0  W: [[0.01270127]
#  [0.00963472]
#  [0.00526406]
#  ...
#  [0.00264977]
#  [0.01844549]
#  [0.00343118]]  b: [0.18535122]  loss: 0.16739056
# ----------------------------------------------------------------------
# Movie :  12 / 20
# Iteration: 0  W: [[0.0121768 ]
#  [0.00899842]
#  [0.0047074 ]
#  ...
#  [0.00254081]
#  [0.01711707]
#  [0.00317697]]  b: [0.17347175]  loss: 0.05962863
# ----------------------------------------------------------------------
# Movie :  13 / 20
# Iteration: 0  W: [[0.0124352 ]
#  [0.00925901]
#  [0.00485363]
#  ...
#  [0.00260426]
#  [0.01789183]
#  [0.00331394]]  b: [0.1791513]  loss: 0.06572683
# ----------------------------------------------------------------------
# Movie :  14 / 20
# Iteration: 0  W: [[0.01208472]
#  [0.00895428]
#  [0.00462752]
#  ...
#  [0.00265145]
#  [0.01724115]
#  [0.00319066]]  b: [0.17303684]  loss: 0.048667572
# ----------------------------------------------------------------------
# Movie :  15 / 20
# Iteration: 0  W: [[0.01234106]
#  [0.00922212]
#  [0.00480576]
#  ...
#  [0.00351308]
#  [0.01765824]
#  [0.00328607]]  b: [0.17829946]  loss: 0.39676258
# ----------------------------------------------------------------------
# Movie :  16 / 20
# Iteration: 0  W: [[0.01303205]
#  [0.00994772]
#  [0.00516724]
#  ...
#  [0.00366243]
#  [0.01919424]
#  [0.00355975]]  b: [0.19331709]  loss: 0.1413659
# ----------------------------------------------------------------------
# Movie :  17 / 20
# Iteration: 0  W: [[0.01272346]
#  [0.00966846]
#  [0.00495774]
#  ...
#  [0.00358037]
#  [0.01835418]
#  [0.00338145]]  b: [0.18580459]  loss: 0.046291318
# ----------------------------------------------------------------------
# Movie :  18 / 20
# Iteration: 0  W: [[0.01287198]
#  [0.00982749]
#  [0.00503903]
#  ...
#  [0.00363603]
#  [0.01882478]
#  [0.00347115]]  b: [0.19007944]  loss: 0.37317365
# ----------------------------------------------------------------------
# Movie :  19 / 20
# Iteration: 0  W: [[0.01183448]
#  [0.00871443]
#  [0.00425069]
#  ...
#  [0.00336954]
#  [0.01713892]
#  [0.00309736]]  b: [0.16712022]  loss: 6.1124253
# ----------------------------------------------------------------------
# Movie :  20 / 20
# Iteration: 0  W: [[0.01182851]
#  [0.00847081]
#  [0.00294166]
#  ...
#  [0.00293783]
#  [0.01542914]
#  [0.00264142]]  b: [0.14143322]  loss: 0.06582308
# starting testing...
# ----------------------------------------------------------------------
# Movie :  1 / 5
# [array([0.249  , 0.8715 , 0.034  , ..., 0.01575, 0.1355 , 0.03   ])]
# For Movie :  1 / 5 the prediction is: [[4.75989663]] and the actual rating is 5.0
# ----------------------------------------------------------------------
# Movie :  2 / 5
# [array([0.04575, 0.04825, 0.02075, ..., 0.01275, 0.10125, 0.017  ])]
# For Movie :  2 / 5 the prediction is: [[4.25050089]] and the actual rating is 3.0
# ----------------------------------------------------------------------
# Movie :  3 / 5
# [array([0.09375, 0.08925, 0.0255 , ..., 0.0255 , 0.111  , 0.023  ])]
# For Movie :  3 / 5 the prediction is: [[4.95029349]] and the actual rating is 5.0
# ----------------------------------------------------------------------
# Movie :  4 / 5
# [array([0.0705 , 0.0785 , 0.0235 , ..., 0.01425, 0.08425, 0.016  ])]
# For Movie :  4 / 5 the prediction is: [[3.51541614]] and the actual rating is 4.0
# ----------------------------------------------------------------------
# Movie :  5 / 5
# [array([0.03525, 0.033  , 0.13925, ..., 0.0165 , 0.0845 , 0.01975])]
# For Movie :  5 / 5 the prediction is: [[3.05562425]] and the actual rating is 3.0
